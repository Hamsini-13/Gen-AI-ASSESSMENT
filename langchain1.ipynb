# %%
# !pip install langchain

from langchain.prompts import PromptTemplate
from langchain.prompts.chat import ChatPromptTemplate
# Out:
# Requirement already satisfied: langchain in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.2.15)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (1.2.28)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (1.1.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.30)
# Requirement already satisfied: packaging>=23.2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.9 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (0.3.13)
# Requirement already satisfied: xxhash>=3.5.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 get_ipython().system('pip install langchain')
# ----> 3 from langchain.prompts import PromptTemplate
#       4 from langchain.prompts.chat import ChatPromptTemplate
#
# ModuleNotFoundError: No module named 'langchain.prompts'

# %%
template = "Explain {topic} in simple terms for beginners"

prompt_template = PromptTemplate(
    input_variables=["topic"],
    template=template
)

# Test
output = prompt_template.format(topic="Artificial Intelligence")
print(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 template = "Explain {topic} in simple terms for beginners"
# ----> 3 prompt_template = PromptTemplate(
#       4     input_variables=["topic"],
#       5     template=template
#       6 )
#       8 # Test
#       9 output = prompt_template.format(topic="Artificial Intelligence")
#
# NameError: name 'PromptTemplate' is not defined

# %%
multi_template = "Explain {topic} for {audience} in a {tone} tone"

multi_prompt = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template=multi_template
)

# Test Cases
print(multi_prompt.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_prompt.format(topic="Python", audience="kids", tone="fun"))
print(multi_prompt.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 multi_template = "Explain {topic} for {audience} in a {tone} tone"
# ----> 3 multi_prompt = PromptTemplate(
#       4     input_variables=["topic", "audience", "tone"],
#       5     template=multi_template
#       6 )
#       8 # Test Cases
#       9 print(multi_prompt.format(topic="AI", audience="beginners", tone="friendly"))
#
# NameError: name 'PromptTemplate' is not defined

# %%
# Teaching Template
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

# Interview Template
interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

# Storytelling Template
story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

# Run
topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Teaching Template
# ----> 2 teaching_template = PromptTemplate(
#       3     input_variables=["topic"],
#       4     template="Explain {topic} clearly step by step"
#       5 )
#       7 # Interview Template
#       8 interview_template = PromptTemplate(
#       9     input_variables=["topic"],
#      10     template="Ask 3 interview questions about {topic}"
#      11 )
#
# NameError: name 'PromptTemplate' is not defined

# %%
chat_template = ChatPromptTemplate.from_messages([
    ("system", "You are a {role}."),
    ("user", "Explain {topic}")
])

# Test
messages = chat_template.format_messages(
    role="teacher",
    topic="Neural Networks"
)

for msg in messages:
    print(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 chat_template = ChatPromptTemplate.from_messages([
#       2     ("system", "You are a {role}."),
#       3     ("user", "Explain {topic}")
#       4 ])
#       6 # Test
#       7 messages = chat_template.format_messages(
#       8     role="teacher",
#       9     topic="Neural Networks"
#      10 )
#
# NameError: name 'ChatPromptTemplate' is not defined

# %%
def validate_inputs(audience, tone):
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]
    
    if audience not in valid_audience:
        print("Invalid audience! Setting default = beginner")
        audience = "beginner"
        
    if tone not in valid_tone:
        print("Invalid tone! Setting default = formal")
        tone = "formal"
        
    return audience, tone

# Test
aud, tone = validate_inputs("kids", "friendly")
print(aud, tone)
# Out:
# Invalid audience! Setting default = beginner
# Invalid tone! Setting default = formal
# beginner formal

# %%
def generate_prompt(topic, audience, tone, style):
    
    # Validate inputs
    audience, tone = validate_inputs(audience, tone)
    
    if style == "teaching":
        template = "Explain {topic} for {audience} in a {tone} teaching style"
        
    elif style == "interview":
        template = "Generate interview questions on {topic} for {audience} in a {tone} tone"
        
    elif style == "storytelling":
        template = "Explain {topic} for {audience} in a {tone} storytelling style"
        
    else:
        return "Invalid style"
    
    prompt = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=template
    )
    
    return prompt.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 26
#      23     return prompt.format(topic=topic, audience=audience, tone=tone)
#      25 # Test
# ---> 26 print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
#
# Cell In[7], line 18, in generate_prompt(topic, audience, tone, style)
#      15 else:
#      16     return "Invalid style"
# ---> 18 prompt = PromptTemplate(
#      19     input_variables=["topic", "audience", "tone"],
#      20     template=template
#      21 )
#      23 return prompt.format(topic=topic, audience=audience, tone=tone)
#
# NameError: name 'PromptTemplate' is not defined

# %%
reuse_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

topics = ["AI", "Blockchain", "Cloud Computing", "Cyber Security", "Data Science"]

for t in topics:
    print(reuse_template.format(topic=t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 reuse_template = PromptTemplate(
#       2     input_variables=["topic"],
#       3     template="Explain {topic} in simple terms"
#       4 )
#       6 topics = ["AI", "Blockchain", "Cloud Computing", "Cyber Security", "Data Science"]
#       8 for t in topics:
#
# NameError: name 'PromptTemplate' is not defined

# %%
def full_pipeline(topic, audience, tone, style):
    
    # Step 1: Validate
    audience, tone = validate_inputs(audience, tone)
    
    # Step 2: Generate Prompt
    result = generate_prompt(topic, audience, tone, style)
    
    # Step 3: Output
    return result

# Test
print(full_pipeline("Deep Learning", "beginner", "fun", "teaching"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 13
#      10     return result
#      12 # Test
# ---> 13 print(full_pipeline("Deep Learning", "beginner", "fun", "teaching"))
#
# Cell In[9], line 7, in full_pipeline(topic, audience, tone, style)
#       4 audience, tone = validate_inputs(audience, tone)
#       6 # Step 2: Generate Prompt
# ----> 7 result = generate_prompt(topic, audience, tone, style)
#       9 # Step 3: Output
#      10 return result
#
# Cell In[7], line 18, in generate_prompt(topic, audience, tone, style)
#      15 else:
#      16     return "Invalid style"
# ---> 18 prompt = PromptTemplate(
#      19     input_variables=["topic", "audience", "tone"],
#      20     template=template
#      21 )
#      23 return prompt.format(topic=topic, audience=audience, tone=tone)
#
# NameError: name 'PromptTemplate' is not defined
