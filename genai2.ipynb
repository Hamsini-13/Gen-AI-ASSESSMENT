# %%
# !pip install langchain langchain-openai faiss-cpu python-dotenv
# Out:
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.12-py3-none-any.whl.metadata (3.1 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.30-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: jsonpointer>=1.9 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.10.0)
# Requirement already satisfied: certifi in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting openai<3.0.0,>=2.26.0 (from langchain-openai)
#   Downloading openai-2.31.0-py3-none-any.whl.metadata (31 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=2.26.0->langchain-openai)
#   Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.3.32)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from faiss-cpu) (2.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Requirement already satisfied: colorama in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.30-py3-none-any.whl (372 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl (187 kB)
# Downloading langchain_openai-1.1.12-py3-none-any.whl (88 kB)
# Downloading openai-2.31.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.6 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.14.0-cp313-cp313-win_amd64.whl (201 kB)
# Downloading tiktoken-0.12.0-cp313-cp313-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.1 kB ? eta -:--:--
#    ---------------------------------------- 879.1/879.1 kB 5.0 MB/s  0:00:00
# Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    - -------------------------------------- 0.8/18.9 MB 4.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.8/18.9 MB 4.7 MB/s eta 0:00:04
#    ------ --------------------------------- 2.9/18.9 MB 4.7 MB/s eta 0:00:04
#    -------- ------------------------------- 3.9/18.9 MB 4.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 5.2/18.9 MB 5.1 MB/s eta 0:00:03
#    ------------- -------------------------- 6.6/18.9 MB 5.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.6/18.9 MB 5.2 MB/s eta 0:00:03
#    -------------------- ------------------- 9.7/18.9 MB 5.8 MB/s eta 0:00:02
#    ------------------------ --------------- 11.5/18.9 MB 6.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 13.9/18.9 MB 6.6 MB/s eta 0:00:01
#    -------------------------------- ------- 15.5/18.9 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/18.9 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 6.8 MB/s  0:00:02
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading orjson-3.11.8-cp313-cp313-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp313-cp313-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, uuid-utils, python-dotenv, ormsgpack, orjson, jsonpatch, jiter, faiss-cpu, distro, tiktoken, requests-toolbelt, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-openai, langgraph-prebuilt, langgraph, langchain
#
#    ---- -----------------------------------  2/20 [python-dotenv]
#    ------ ---------------------------------  3/20 [ormsgpack]
#    ------------ ---------------------------  6/20 [jiter]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    -------------- -------------------------  7/20 [faiss-cpu]
#    ------------------ ---------------------  9/20 [tiktoken]
#    -------------------- ------------------- 10/20 [requests-toolbelt]
#    -------------------- ------------------- 10/20 [requests-toolbelt]
#    -------------------- ------------------- 10/20 [requests-toolbelt]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ---------------------- ----------------- 11/20 [openai]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    ------------------------ --------------- 12/20 [langsmith]
#    -------------------------- ------------- 13/20 [langgraph-sdk]
#    -------------------------- ------------- 13/20 [langgraph-sdk]
#    -------------------------- ------------- 13/20 [langgraph-sdk]
#    -------------------------- ------------- 13/20 [langgraph-sdk]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ---------------------------- ----------- 14/20 [langchain-core]
#    ------------------------------ --------- 15/20 [langgraph-checkpoint]
#    ------------------------------ --------- 15/20 [langgraph-checkpoint]
#    -------------------------------- ------- 16/20 [langchain-openai]
#    -------------------------------- ------- 16/20 [langchain-openai]
#    ------------------------------------ --- 18/20 [langgraph]
#    ------------------------------------ --- 18/20 [langgraph]
#    ------------------------------------ --- 18/20 [langgraph]
#    ------------------------------------ --- 18/20 [langgraph]
#    ------------------------------------ --- 18/20 [langgraph]
#    -------------------------------------- - 19/20 [langchain]
#    -------------------------------------- - 19/20 [langchain]
#    -------------------------------------- - 19/20 [langchain]
#    ---------------------------------------- 20/20 [langchain]
#
# Successfully installed distro-1.9.0 faiss-cpu-1.13.2 jiter-0.14.0 jsonpatch-1.33 langchain-1.2.15 langchain-core-1.2.28 langchain-openai-1.1.12 langgraph-1.1.6 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.13 langsmith-0.7.30 openai-2.31.0 orjson-3.11.8 ormsgpack-1.12.2 python-dotenv-1.2.2 requests-toolbelt-1.0.0 tiktoken-0.12.0 uuid-utils-0.14.1 zstandard-0.25.0

# %%
import os
os.environ["OPENAI_API_KEY"] = "your_api_key_here"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

response = llm.invoke("Explain Artificial Intelligence in simple terms")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 from langchain_openai import ChatOpenAI
#       3 llm = ChatOpenAI(model="gpt-4o-mini")
# ----> 5 response = llm.invoke("Explain Artificial Intelligence in simple terms")
#       6 print(response.content)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1488, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1486     _handle_openai_bad_request(e)
#    1487 except openai.APIError as e:
# -> 1488     _handle_openai_api_error(e)
#    1489 except Exception as e:
#    1490     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1483, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1476         return _construct_lc_result_from_responses_api(
#    1477             response,
#    1478             schema=original_schema_obj,
#    1479             metadata=generation_info,
#    1480             output_version=self.output_version,
#    1481         )
#    1482     else:
# -> 1483         raw_response = self.client.with_raw_response.create(**payload)
#    1484         response = raw_response.parse()
#    1485 except openai.BadRequestError as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1314, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1305     warnings.warn(
#    1306         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1307         "Please pass raw bytes via the `content` parameter instead.",
#    1308         DeprecationWarning,
#    1309         stacklevel=2,
#    1310     )
#    1311 opts = FinalRequestOptions.construct(
#    1312     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1313 )
# -> 1314 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1087, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1084             err.response.read()
#    1086         log.debug("Re-raising status error")
# -> 1087         raise self._make_status_error_from_response(err.response) from None
#    1089     break
#    1091 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: your_api*****here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
from langchain.prompts import PromptTemplate

template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)

print(template.format(topic="Machine Learning"))

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=template)

result = chain.run("Deep Learning")
print(result)

# %%
from langchain.memory import ConversationBufferMemory

memory = ConversationBufferMemory()

memory.save_context({"input": "Hi"}, {"output": "Hello!"})
memory.save_context({"input": "What is AI?"}, {"output": "AI is intelligence shown by machines."})

print(memory.load_memory_variables({}))

# %%
from langchain.agents import initialize_agent, Tool

def calculator(expression):
    return eval(expression)

tools = [
    Tool(
        name="Calculator",
        func=calculator,
        description="Useful for math calculations"
    )
]

agent = initialize_agent(tools, llm, agent="zero-shot-react-description")

response = agent.run("What is 45 * 3?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from langchain.agents import initialize_agent, Tool
#       3 def calculator(expression):
#       4     return eval(expression)
#
# ImportError: cannot import name 'initialize_agent' from 'langchain.agents' (C:\Users\Hamsini\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain\agents\__init__.py)

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

texts = ["AI is the future", "Machine Learning is a subset of AI"]

db = FAISS.from_texts(texts, embeddings)

query = "What is AI?"
docs = db.similarity_search(query)

print(docs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain.vectorstores import FAISS
#       2 from langchain.embeddings import OpenAIEmbeddings
#       4 embeddings = OpenAIEmbeddings()
#
# ModuleNotFoundError: No module named 'langchain.vectorstores'
